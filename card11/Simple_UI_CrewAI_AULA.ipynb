# %%
# !pip install streamlit==1.32.2
# Out:
# Collecting streamlit==1.32.2
#   Obtaining dependency information for streamlit==1.32.2 from https://files.pythonhosted.org/packages/9b/ea/7219c01b5e92d02d2bc994a36245d99331cd66eb12d284707a2060a013d0/streamlit-1.32.2-py2.py3-none-any.whl.metadata
#   Downloading streamlit-1.32.2-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting altair<6,>=4.0 (from streamlit==1.32.2)
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/aa/f3/0b6ced594e51cc95d8c1fc1640d3623770d01e4969d29c0bd09945fafefa/altair-5.5.0-py3-none-any.whl.metadata
#   Using cached altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: blinker<2,>=1.0.0 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from streamlit==1.32.2) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from streamlit==1.32.2) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from streamlit==1.32.2) (8.1.8)
# Collecting numpy<2,>=1.19.3 (from streamlit==1.32.2)
#   Obtaining dependency information for numpy<2,>=1.19.3 from https://files.pythonhosted.org/packages/19/77/538f202862b9183f54108557bfda67e17603fc560c384559e769321c9d92/numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 1.1 MB/s eta 0:00:00
# Collecting packaging<24,>=16.8 (from streamlit==1.32.2)
#   Obtaining dependency information for packaging<24,>=16.8 from https://files.pythonhosted.org/packages/ec/1a/610693ac4ee14fcdf2d9bf3c493370e4f2ef7ae2e19217d7a237ff42367d/packaging-23.2-py3-none-any.whl.metadata
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas<3,>=1.3.0 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from streamlit==1.32.2) (2.2.3)
# Collecting pillow<11,>=7.1.0 (from streamlit==1.32.2)
#   Obtaining dependency information for pillow<11,>=7.1.0 from https://files.pythonhosted.org/packages/f4/72/0203e94a91ddb4a9d5238434ae6c1ca10e610e8487036132ea9bf806ca2a/pillow-10.4.0-cp310-cp310-win_amd64.whl.metadata
#   Downloading pillow-10.4.0-cp310-cp310-win_amd64.whl.metadata (9.3 kB)
# Collecting protobuf<5,>=3.20 (from streamlit==1.32.2)
#   Obtaining dependency information for protobuf<5,>=3.20 from https://files.pythonhosted.org/packages/79/84/c700d6c3f3be770495b08a1c035e330497a31420e4a39a24c22c02cefc6c/protobuf-4.25.6-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-4.25.6-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: pyarrow>=7.0 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from streamlit==1.32.2) (19.0.1)
# Requirement already satisfied: requests<3,>=2.27 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from streamlit==1.32.2) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from streamlit==1.32.2) (13.9.4)
# Collecting tenacity<9,>=8.1.0 (from streamlit==1.32.2)
#   Obtaining dependency information for tenacity<9,>=8.1.0 from https://files.pythonhosted.org/packages/d2/3f/8ba87d9e287b9d385a02a7114ddcef61b26f86411e121c9003eb509a1773/tenacity-8.5.0-py3-none-any.whl.metadata
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit==1.32.2)
#   Obtaining dependency information for toml<2,>=0.10.1 from https://files.pythonhosted.org/packages/44/6f/7120676b6d73228c96e17f1f794d8ab046fc910d781c8d151120c3f1569e/toml-0.10.2-py2.py3-none-any.whl.metadata
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from streamlit==1.32.2) (4.13.1)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit==1.32.2)
#   Obtaining dependency information for gitpython!=3.1.19,<4,>=3.0.7 from https://files.pythonhosted.org/packages/1d/9a/4114a9057db2f1462d5c8f8390ab7383925fe1ac012eaa42402ad65c2963/GitPython-3.1.44-py3-none-any.whl.metadata
#   Using cached GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit==1.32.2)
#   Obtaining dependency information for pydeck<1,>=0.8.0b4 from https://files.pythonhosted.org/packages/ab/4c/b888e6cf58bd9db9c93f40d1c6be8283ff49d88919231afe93a6bcf61626/pydeck-0.9.1-py2.py3-none-any.whl.metadata
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from streamlit==1.32.2) (6.4.2)
# Collecting watchdog>=2.1.5 (from streamlit==1.32.2)
#   Obtaining dependency information for watchdog>=2.1.5 from https://files.pythonhosted.org/packages/db/d9/c495884c6e548fce18a8f40568ff120bc3a4b7b99813081c8ac0c936fa64/watchdog-6.0.0-py3-none-win_amd64.whl.metadata
#   Using cached watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: jinja2 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from altair<6,>=4.0->streamlit==1.32.2) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from altair<6,>=4.0->streamlit==1.32.2) (4.23.0)
# Collecting narwhals>=1.14.2 (from altair<6,>=4.0->streamlit==1.32.2)
#   Obtaining dependency information for narwhals>=1.14.2 from https://files.pythonhosted.org/packages/b0/a2/2ea3f2058ae661b06fad1a14c0f29f1cc8e49478d02a2d68f0eac3872b86/narwhals-1.34.1-py3-none-any.whl.metadata
#   Downloading narwhals-1.34.1-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: colorama in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from click<9,>=7.0->streamlit==1.32.2) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.32.2)
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/a0/61/5c78b91c3143ed5c14207f463aecfc8f9dbb5092fb2869baf37c273b2705/gitdb-4.0.12-py3-none-any.whl.metadata
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from pandas<3,>=1.3.0->streamlit==1.32.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from pandas<3,>=1.3.0->streamlit==1.32.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from pandas<3,>=1.3.0->streamlit==1.32.2) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from requests<3,>=2.27->streamlit==1.32.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from requests<3,>=2.27->streamlit==1.32.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from requests<3,>=2.27->streamlit==1.32.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from requests<3,>=2.27->streamlit==1.32.2) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from rich<14,>=10.14.0->streamlit==1.32.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from rich<14,>=10.14.0->streamlit==1.32.2) (2.19.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.32.2)
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/04/be/d09147ad1ec7934636ad912901c5fd7667e1c858e19d355237db0d0cd5e4/smmap-5.0.2-py3-none-any.whl.metadata
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit==1.32.2) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.32.2) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.32.2) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.32.2) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.32.2) (0.24.0)
# Requirement already satisfied: mdurl~=0.1 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit==1.32.2) (0.1.2)
# Requirement already satisfied: six>=1.5 in d:\users\paulo\pycharmprojects\fastcamp-agent\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit==1.32.2) (1.17.0)
# Downloading streamlit-1.32.2-py2.py3-none-any.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.1 MB 5.5 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/8.1 MB 4.5 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/8.1 MB 5.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.8/8.1 MB 5.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.2/8.1 MB 6.8 MB/s eta 0:00:02
#    ------- -------------------------------- 1.6/8.1 MB 7.1 MB/s eta 0:00:01
#    --------- ------------------------------ 2.0/8.1 MB 8.0 MB/s eta 0:00:01
#    ------------ --------------------------- 2.5/8.1 MB 8.9 MB/s eta 0:00:01
#    -------------- ------------------------- 3.0/8.1 MB 9.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.4/8.1 MB 9.5 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.1 MB 10.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.1 MB 10.6 MB/s eta 0:00:01
#    ------------------------ --------------- 4.9/8.1 MB 10.5 MB/s eta 0:00:01
#    --------------------------- ------------ 5.6/8.1 MB 11.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.1/8.1 MB 11.4 MB/s eta 0:00:01
#    -------------------------------- ------- 6.7/8.1 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 12.1 MB/s eta 0:00:00
# Using cached altair-5.5.0-py3-none-any.whl (731 kB)
# Using cached GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/15.8 MB 25.4 MB/s eta 0:00:01
#    --- ------------------------------------ 1.5/15.8 MB 18.9 MB/s eta 0:00:01
#    ----- ---------------------------------- 2.2/15.8 MB 19.9 MB/s eta 0:00:01
#    ------- -------------------------------- 3.0/15.8 MB 20.9 MB/s eta 0:00:01
#    --------- ------------------------------ 3.8/15.8 MB 20.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 4.6/15.8 MB 21.0 MB/s eta 0:00:01
#    ------------- -------------------------- 5.5/15.8 MB 22.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.4/15.8 MB 21.5 MB/s eta 0:00:01
#    ------------------ --------------------- 7.2/15.8 MB 21.9 MB/s eta 0:00:01
#    -------------------- ------------------- 8.2/15.8 MB 22.7 MB/s eta 0:00:01
#    -------------------- ------------------- 8.2/15.8 MB 22.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.2/15.8 MB 21.1 MB/s eta 0:00:01
#    ------------------------ --------------- 9.8/15.8 MB 20.8 MB/s eta 0:00:01
#    -------------------------- ------------- 10.6/15.8 MB 20.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.7/15.8 MB 21.8 MB/s eta 0:00:01
#    ------------------------------- -------- 12.6/15.8 MB 22.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.4/15.8 MB 22.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.8/15.8 MB 21.1 MB/s eta 0:00:01
#    -------------------------------------- - 15.0/15.8 MB 21.8 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 22.6 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 21.1 MB/s eta 0:00:00
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Downloading pillow-10.4.0-cp310-cp310-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ----------------- ---------------------- 1.1/2.6 MB 35.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.3/2.6 MB 36.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 27.4 MB/s eta 0:00:00
# Downloading protobuf-4.25.6-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    --------------------------------------- 413.4/413.4 kB 25.2 MB/s eta 0:00:00
# Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading narwhals-1.34.1-py3-none-any.whl (325 kB)
#    ---------------------------------------- 0.0/325.5 kB ? eta -:--:--
#    --------------------------------------- 325.5/325.5 kB 10.2 MB/s eta 0:00:00
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, toml, tenacity, smmap, protobuf, pillow, packaging, numpy, narwhals, pydeck, gitdb, gitpython, altair, streamlit
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.1.2
#     Uninstalling tenacity-9.1.2:
#       Successfully uninstalled tenacity-9.1.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.4
#     Uninstalling numpy-2.2.4:
#       Successfully uninstalled numpy-2.2.4
# Successfully installed altair-5.5.0 gitdb-4.0.12 gitpython-3.1.44 narwhals-1.34.1 numpy-1.26.4 packaging-23.2 pillow-10.4.0 protobuf-4.25.6 pydeck-0.9.1 smmap-5.0.2 streamlit-1.32.2 tenacity-8.5.0 toml-0.10.2 watchdog-6.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-tools 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.6 which is incompatible.
# instructor 1.7.9 requires tenacity<10.0.0,>=9.0.0, but you have tenacity 8.5.0 which is incompatible.
# opentelemetry-proto 1.31.1 requires protobuf<6.0,>=5.0, but you have protobuf 4.25.6 which is incompatible.
# WARNING: There was an error checking the latest version of pip.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from the .env file
load_dotenv()
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')

# %%
import streamlit as st

from crewai import Crew, Process, Agent, Task
from langchain_core.callbacks import BaseCallbackHandler
from typing import TYPE_CHECKING, Any, Dict, Optional
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI()

# Ícones para o app web
avators = {"Writer":"https://cdn-icons-png.flaticon.com/512/320/320336.png",
            "Reviewer":"https://cdn-icons-png.freepik.com/512/9408/9408201.png"}

# %%
## Classe para gerenciar os callbacks do app
class MyCustomHandler(BaseCallbackHandler):


    def __init__(self, agent_name: str) -> None:
        self.agent_name = agent_name

    # Função para escrever as mensagens dos agentes
    def on_chain_start(
        self, serialized: Dict[str, Any], inputs: Dict[str, Any], **kwargs: Any
    ) -> None:
        """Print out that we are entering a chain."""
        st.session_state.messages.append({"role": "assistant", "content": inputs['input']})
        st.chat_message("assistant").write(inputs['input'])

    # Função para escrever o output final
    def on_chain_end(self, outputs: Dict[str, Any], **kwargs: Any) -> None:
        """Print out that we finished a chain."""
        st.session_state.messages.append({"role": self.agent_name, "content": outputs['output']})
        st.chat_message(self.agent_name, avatar=avators[self.agent_name]).write(outputs['output'])

# %%
# Agente escritor, responsável pelos textos base que serão escritos
writer = Agent(
    role='Blog Post Writer',
    backstory='''You are a blog post writer who is capable of writing a travel blog.
                      You generate one iteration of an article once at a time.
                      You never provide review comments.
                      You are open to reviewer's comments and willing to iterate its article based on these comments.
                      ''',
    goal="Write and iterate a decent blog post.",
    # tools=[]  # This can be optionally specified; defaults to an empty list
    llm=llm,
    callbacks=[MyCustomHandler("Writer")],
)
# Agente que analisa e melhora as escritas feitas
reviewer = Agent(
    role='Blog Post Reviewer',
    backstory='''You are a professional article reviewer and very helpful for improving articles.
                 You review articles and give change recommendations to make the article more aligned with user requests.
                 You will give review comments upon reading entire article, so you will not generate anything when the article is not completely delivered.
                  You never generate blogs by itself.''',
    goal="list builtins about what need to be improved of a specific blog post. Do not give comments on a summary or abstract of an article",
    # tools=[]  # Optionally specify tools; defaults to an empty list
    llm=llm,
    callbacks=[MyCustomHandler("Reviewer")],
)

# %%
# Configurações do chat

#Título
st.title("💬 CrewAI Writing Studio")

# Carregamento da mensagem inicial no session storage
if "messages" not in st.session_state:
    st.session_state["messages"] = [{"role": "assistant", "content": "What blog post do you want us to write?"}]

# Escrever a mensagem inicial no chat
for msg in st.session_state.messages:
    st.chat_message(msg["role"]).write(msg["content"])

# Esperar o prompt para continuar a execução
if prompt := st.chat_input():

    st.session_state.messages.append({"role": "user", "content": prompt})
    st.chat_message("user").write(prompt)

    # Task do agente escritor
    task1 = Task(
      description=f"""Write a blog post of {prompt}. """,
      agent=writer,
      expected_output="an article under 300 words."
    )

    # Task do editor
    task2 = Task(
      description="""list review comments for improvement from the entire content of blog post to make it more viral on social media""",
      agent=reviewer,
      expected_output="Builtin points about where need to be improved."
    )
    # Establishing the crew with a hierarchical process
    project_crew = Crew(
        tasks=[task1, task2],  # Tasks to be delegated and executed under the manager's supervision
        agents=[writer, reviewer],
        manager_llm=llm,
        process=Process.hierarchical  # Specifies the hierarchical management approach
    )
    final = project_crew.kickoff()

    result = f"## Here is the Final Result \n\n {final}"
    st.session_state.messages.append({"role": "assistant", "content": result})
    st.chat_message("assistant").write(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Users\paulo\PycharmProjects\fastcamp-agent\venv\lib\site-packages\streamlit\runtime\state\session_state.py:398, in SessionState.__getitem__(self, key)
#     397 try:
# --> 398     return self._getitem(widget_id, key)
#     399 except KeyError:
#
# File D:\Users\paulo\PycharmProjects\fastcamp-agent\venv\lib\site-packages\streamlit\runtime\state\session_state.py:443, in SessionState._getitem(self, widget_id, user_key)
#     442 # We'll never get here
# --> 443 raise KeyError
#
# KeyError:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File D:\Users\paulo\PycharmProjects\fastcamp-agent\venv\lib\site-packages\streamlit\runtime\state\session_state_proxy.py:119, in SessionStateProxy.__getattr__(self, key)
#     118 try:
# --> 119     return self[key]
#     120 except KeyError:
#
# File D:\Users\paulo\PycharmProjects\fastcamp-agent\venv\lib\site-packages\streamlit\runtime\state\session_state_proxy.py:90, in SessionStateProxy.__getitem__(self, key)
#      89 require_valid_user_key(key)
# ---> 90 return get_session_state()[key]
#
# File D:\Users\paulo\PycharmProjects\fastcamp-agent\venv\lib\site-packages\streamlit\runtime\state\safe_session_state.py:93, in SafeSessionState.__getitem__(self, key)
#      92 with self._lock:
# ---> 93     return self._state[key]
#
# File D:\Users\paulo\PycharmProjects\fastcamp-agent\venv\lib\site-packages\streamlit\runtime\state\session_state.py:400, in SessionState.__getitem__(self, key)
#     399 except KeyError:
# --> 400     raise KeyError(_missing_key_error_message(key))
#
# KeyError: 'st.session_state has no key "messages". Did you forget to initialize it? More info: https://docs.streamlit.io/library/advanced-features/session-state#initialization'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 11
#       8     st.session_state["messages"] = [{"role": "assistant", "content": "What blog post do you want us to write?"}]
#      10 # Escrever a mensagem inicial no chat
# ---> 11 for msg in st.session_state.messages:
#      12     st.chat_message(msg["role"]).write(msg["content"])
#      14 # Esperar o prompt para continuar a execução
#
# File D:\Users\paulo\PycharmProjects\fastcamp-agent\venv\lib\site-packages\streamlit\runtime\state\session_state_proxy.py:121, in SessionStateProxy.__getattr__(self, key)
#     119     return self[key]
#     120 except KeyError:
# --> 121     raise AttributeError(_missing_attr_error_message(key))
#
# AttributeError: st.session_state has no attribute "messages". Did you forget to initialize it? More info: https://docs.streamlit.io/library/advanced-features/session-state#initialization
